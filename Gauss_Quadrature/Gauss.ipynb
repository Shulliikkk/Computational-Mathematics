# %%
import numpy as np
import matplotlib.pyplot as plt

Err = np.array([1.56786e-06, 1.56786e-06, 1.56786e-06, 1.56786e-06, 1.56786e-06, 1.56786e-06, 1.56786e-06, 1.56786e-06, 1.06476e-07, 1.52749e-08, 1.07152e-08, 9.29035e-09, 9.2013e-09, 9.19685e-09, 9.19548e-09])
eps = np.array([0.1**i for i in range(15)])

plt.scatter(np.log(eps), np.log(Err))

plt.xlabel('log(eps)')
plt.ylabel('log(Err)')

plt.show()
